# %% [markdown]
# <a href="https://colab.research.google.com/github/Disha-1102/Cognifyz/blob/main/Level3_Cognifyz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Level 3: Task 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

FILE_PATH = "/content/Dataset.csv"   # change if needed
df = pd.read_csv(FILE_PATH)
print("Rows loaded:", len(df))
# Out:
# Rows loaded: 9551
